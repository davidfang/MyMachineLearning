# %% [markdown]
# ## 读取excel表格文件中的内容

# %%
import pandas as pd

# %%
df = pd.read_excel('./read_excel/弹性福利上海人寿2019保单19-10至20-12月.xlsx', '责任层', index_col=None, na_values=['NA'])

# %%
df
# Out:
#              个人赔案号
# 0     201910110356
# 1     201910120248
# 2     201910120276
# 3     201910140117
# 4     201910140468
# ...            ...
# 2254  202011260004
# 2255  202012070025
# 2256  202012140022
# 2257  202012210003
# 2258  202012310001
#
# [2259 rows x 1 columns]

# %%
s = ['a', 'b', 'c', 'd']
print(''.join(s))
print('-'.join(s))
# Out:
# abcd
# a-b-c-d

# %%
df_list = df['个人赔案号'].values.tolist()

# %%
print(df_list)
# Out:
# ['201910110356', '201910120248', '201910120276', '201910140117', '201910140468', '201910140624', '201910150072', '201910150088', '201910150238', '201910150295', '201910150324', '201910150334', '201910150340', '201910150350', '201910150360', '201910150418', '201910150421', '201910160205', '201910160364', '201910160380', '201910170020', '201910170021', '201910170205', '201910170249', '201910170311', '201910170408', '201910170428', '201910170461', '201910180111', '201910180251', '201910180372', '201910180373', '201910180461', '201910210175', '201910210293', '201910210336', '201910220013', '201910220014', '201910220042', '201910220096', '201910220258', '201910220284', '201910220311', '201910220312', '201910220313', '201910220314', '201910220319', '201910220320', '201910220431', '201910220471', '201910230089', '201910230109', '201910230228', '201910230243', '201910230260', '201910230451', '201910230454', '201910230503', '201910230508', '201910230509', '201910230515', '201910230536', '2019
# ...

# %%
gp = df.drop_duplicates()

# %%
gp
# Out:
#              个人赔案号
# 0     201910110356
# 1     201910120248
# 2     201910120276
# 3     201910140117
# 4     201910140468
# ...            ...
# 2254  202011260004
# 2255  202012070025
# 2256  202012140022
# 2257  202012210003
# 2258  202012310001
#
# [2158 rows x 1 columns]
